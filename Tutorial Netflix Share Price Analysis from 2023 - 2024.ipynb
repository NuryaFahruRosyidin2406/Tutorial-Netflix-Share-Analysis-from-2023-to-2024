# %% [markdown]
# # Netflix Share Price Analysis from 2023 - 2024

# %% [markdown]
# Referensi ini dari: https://www.linkedin.com/feed/update/urn:li:activity:7161606215758700544/

# %% [markdown]
# ## 1. An Introduction to Dataset

# %% [markdown]
# Dalam laporan analitis ini, kami mempelajari lanskap rumit harga saham Netflix, dengan menggunakan dataset komprehensif yang mencakup rentang waktu 2023 hingga 2024. Bagian pengantar ini memberikan gambaran singkat mengenai dataset, sumbernya, isinya, dan menguraikan pendekatan analitis yang digunakan untuk analisis data eksploratif (EDA).

# %% [markdown]
# ### 1.1 About the Dataset

# %% [markdown]
# Kumpulan data yang menjadi inti analisis ini merangkum banyak informasi mengenai harga saham Netflix. Dengan catatan yang cermat dari tahun 2023 hingga 2024, data ini menjadi sumber daya yang berharga untuk membedah fluktuasi; tren, dan nuansa yang melekat pada dinamika pasar saham di sekitar raksasa streaming ini.

# %% [markdown]
# ### 1.2 Source of Data

# %% [markdown]
# Dataset ini dikurasi dengan cermat dari sumber-sumber yang dapat dipercaya, untuk memastikan akurasi dan integritas dalam representasi kinerja saham Netflix. Melalui proses agregasi dan verifikasi yang cermat, sumber data ini menjamin fondasi yang kuat untuk upaya analisis kami.

# %% [markdown]
# ### 1.3 Contents of Data

# %% [markdown]
# Meliputi berbagai aspek perjalanan pasar saham Netflix, dataset ini terdiri dari kolom-kolom penting yang menjelaskan aspek-aspek penting dalam penetapan harga saham. Ini termasuk:
#
# *	Data: Mencatat hari perdagangan selama jangka waktu tertentu.
#
# *	Open: Menandakan harga pembukaan saham Netflix pada setiap hari perdagangan.
#
# *	High: Mencerminkan harga tertinggi yang diperdagangkan saham Netflix pada hari itu.
#
# *	Low: Menunjukkan harga terendah di mana saham Netflix diperdagangkan pada hari itu.
#
# *	Close: Menunjukkan harga penutupan saham Netflix pada setiap hari perdagangan.
#
# *	Adjustment Close: Menyajikan harga penutupan yang disesuaikan, dengan memperhitungkan peristiwa seperti dividen dan pemecahan saham.
#
# *	Volume: Menunjukkan jumlah total saham yang diperdagangkan pada setiap hari perdagangan.

# %% [markdown]
# ### 1.4 Analytical Approach

# %% [markdown]
# Pendekatan analisis yang diadopsi untuk analisis ini terutama berkisar pada Analisis Data Eksplorasi (EDA). Melalui pemeriksaan dan visualisasi set data yang cermat, kami bertujuan untuk menggali pola, tren, dan hubungan yang mendalam dalam harga saham Netflix. Dengan mengamati data dari berbagai sudut, kami berusaha mengekstrak wawasan yang dapat ditindaklanjuti yang dapat menginformasikan pengambilan keputusan strategis dan memperdalam pemahaman kami tentang dinamika yang memengaruhi kinerja saham Netflix.

# %% [markdown]
# ## 2. Overview of The Data

# %% [markdown]
# Saya akan memulai perjalanan eksplorasi data kita dengan memanggil Pandas Library yang perkasa, sekutu kuat yang terkenal akan kehebatannya dalam menggunakan kumpulan data. Bersama-sama, kita akan memulai pencarian untuk mengungkap rahasia yang tersembunyi di dalam data kita, menyingkap kedalamannya yang penuh teka-teki dan mengungkapkan kisah-kisah yang ingin disampaikannya.

# %%
import pandas as pd
netflix = pd.read_csv("/content/NFLX.csv") # Load the dataset and assign to variable netflix

# Read the first 10 rows of the dataset
print("Furst 10 rows of the dataset:")
netflix.head(10)
# Out:
# Furst 10 rows of the dataset:
#          Date   Open   High    Low  Close  Adj Close   Volume
# 0  2023-02-01 353.86 365.39 349.91 361.99     361.99  8005200
# 1  2023-02-02 365.16 368.32 358.43 366.89     366.89  7857000
# 2  2023-02-03 359.08 379.43 359.00 365.90     365.90  9402000
# 3  2023-02-06 363.64 368.45 360.68 361.48     361.48  4994900
# 4  2023-02-07 358.51 364.18 354.18 362.95     362.95  6289400
# 5  2023-02-08 360.02 368.19 358.31 366.83     366.83  6253200
# 6  2023-02-09 372.41 373.83 361.74 362.50     362.50  6901100
# 7  2023-02-10 359.16 362.14 347.14 347.36     347.36  7291100
# 8  2023-02-13 349.50 359.70 344.25 358.57     358.57  7134400
# 9  2023-02-14 357.55 363.75 353.40 359.96     359.96  4624800

# %%
# Read the last 10 rows of the dataset
print("Last 10 rows of the dataset:")
netflix.tail(10)
# Out:
# Last 10 rows of the dataset:
#            Date   Open   High    Low  Close  Adj Close    Volume
# 241  2024-01-18 480.03 485.77 478.02 485.31     485.31   4054400
# 242  2024-01-19 484.98 485.67 476.06 482.95     482.95   5665600
# 243  2024-01-22 487.55 489.80 479.90 485.71     485.71   5212300
# 244  2024-01-23 492.00 498.96 481.40 492.19     492.19  15506000
# 245  2024-01-24 537.75 562.50 537.07 544.87     544.87  26432800
# 246  2024-01-25 551.95 563.46 548.46 562.00     562.00   9451900
# 247  2024-01-26 561.81 579.64 558.43 570.42     570.42  12754500
# 248  2024-01-29 571.35 578.55 562.68 575.79     575.79   6905400
# 249  2024-01-30 567.32 570.88 560.82 562.85     562.85   6181800
# 250  2024-01-31 562.85 572.15 562.04 564.11     564.11   4857600

# %%
# Setting display  options to show all values without scientific notation
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
netflix.head(3)
# Out:
#          Date   Open   High    Low  Close  Adj Close   Volume
# 0  2023-02-01 353.86 365.39 349.91 361.99     361.99  8005200
# 1  2023-02-02 365.16 368.32 358.43 366.89     366.89  7857000
# 2  2023-02-03 359.08 379.43 359.00 365.90     365.90  9402000

# %%
# Now when call describe(), the volume column should be displayed without scientific notation of 'e'
print("\nDescriptive statistics of the dataset:")
netflix.describe()
# Out:
# Descriptive statistics of the dataset:
#         Open   High    Low  Close  Adj Close      Volume
# count 251.00 251.00 251.00 251.00     251.00      251.00
# mean  404.18 409.75 398.96 404.27     404.27  6135307.97
# std    60.85  61.32  60.72  61.19      61.19  3814621.40
# min   287.34 297.45 285.33 292.76     292.76  1404700.00
# 25%   348.99 356.86 344.49 348.12     348.12  3966000.00
# 50%   412.00 418.84 407.40 411.69     411.69  5128900.00
# 75%   444.73 448.57 439.18 444.94     444.94  6880600.00
# max   571.35 579.64 562.68 575.79     575.79 28074400.00

# %%
# See the Rows and Column of the dataset
netflix.shape
# Out:
# (251, 7)

# %%
# Information on the dataset
print("\nInformation about the Dataframe after converting 'Date' column to datetime format:")
print("\n")
netflix.info()
# Out:
# Information about the Dataframe after converting 'Date' column to datetime format:
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    object
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %% [markdown]
# Here, we can see that the _Date_ column is _object_. I will be converting it to _datetime64[ns]_ format for better allotment of the DataType

# %%
netflix['Date'] = pd.to_datetime(netflix['Date'])

# Check the information about the DataFrame to see if changes were made
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    datetime64[ns]
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.9 KB

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# Sekarang setelah kami mengungkap lapisan awal dari dataset kami, sekarang saatnya untuk memoles harta karun kami dan memastikan integritasnya untuk eksplorasi lebih lanjut. Dalam fase petualangan ini, kita akan memulai pencarian mulia pembersihan data, di mana kita akan menyaring pasir dari kumpulan data kita, mengalahkan inkonsistensi, menjinakkan pencilan, dan menghaluskan sisi-sisi yang kasar. Tujuan kita? Untuk memahat data kami menjadi mahakarya yang murni, yang siap menghasilkan permata tersembunyi sesuai perintah kami.

# %%
# See if our data contains any 'null' values
netflix.notnull()

# This will return a Bollean series either True (if our data does not contain missing values) or
# Dalse (if there are Missing Values)
# Out:
#      Date  Open  High   Low  Close  Adj Close  Volume
# 0    True  True  True  True   True       True    True
# 1    True  True  True  True   True       True    True
# 2    True  True  True  True   True       True    True
# 3    True  True  True  True   True       True    True
# 4    True  True  True  True   True       True    True
# ..    ...   ...   ...   ...    ...        ...     ...
# 246  True  True  True  True   True       True    True
# 247  True  True  True  True   True       True    True
# 248  True  True  True  True   True       True    True
# 249  True  True  True  True   True       True    True
# 250  True  True  True  True   True       True    True
#
# [251 rows x 7 columns]

# %%
# Calculate the number of null values in each column
null_counts = netflix.isnull().sum()

# Display the number of null values in each column
print("Number of null values in each column:")
print(null_counts)
# Out:
# Number of null values in each column:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Check Duplication

netflix.duplicated() # Return boolean Series denoting duplicate rows. False means no duplication
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 246    False
# 247    False
# 248    False
# 249    False
# 250    False
# Length: 251, dtype: bool

# %%
print("Jumlah duplikat: ", netflix.duplicated().sum())
netflix.describe()
# Out:
# Jumlah duplikat:  0
#         Open   High    Low  Close  Adj Close      Volume
# count 251.00 251.00 251.00 251.00     251.00      251.00
# mean  404.18 409.75 398.96 404.27     404.27  6135307.97
# std    60.85  61.32  60.72  61.19      61.19  3814621.40
# min   287.34 297.45 285.33 292.76     292.76  1404700.00
# 25%   348.99 356.86 344.49 348.12     348.12  3966000.00
# 50%   412.00 418.84 407.40 411.69     411.69  5128900.00
# 75%   444.73 448.57 439.18 444.94     444.94  6880600.00
# max   571.35 579.64 562.68 575.79     575.79 28074400.00

# %%
# Calculate the total number of null values in the DataFrame
total_null_values = null_counts.sum()

# Display the total number of null values
print("Total number of null values in the DataFrame:", total_null_values)
# Out:
# Total number of null values in the DataFrame: 0

# %%
# Check if our Dataset contains NaN or Null Values
netflix.isna()
# This will return Boolean Series; True if NaN exist or False if NaN does Not exist
# Out:
#       Date   Open   High    Low  Close  Adj Close  Volume
# 0    False  False  False  False  False      False   False
# 1    False  False  False  False  False      False   False
# 2    False  False  False  False  False      False   False
# 3    False  False  False  False  False      False   False
# 4    False  False  False  False  False      False   False
# ..     ...    ...    ...    ...    ...        ...     ...
# 246  False  False  False  False  False      False   False
# 247  False  False  False  False  False      False   False
# 248  False  False  False  False  False      False   False
# 249  False  False  False  False  False      False   False
# 250  False  False  False  False  False      False   False
#
# [251 rows x 7 columns]

# %%
# Drop the NaN values
netflix.dropna()
# Out:
#           Date   Open   High    Low  Close  Adj Close    Volume
# 0   2023-02-01 353.86 365.39 349.91 361.99     361.99   8005200
# 1   2023-02-02 365.16 368.32 358.43 366.89     366.89   7857000
# 2   2023-02-03 359.08 379.43 359.00 365.90     365.90   9402000
# 3   2023-02-06 363.64 368.45 360.68 361.48     361.48   4994900
# 4   2023-02-07 358.51 364.18 354.18 362.95     362.95   6289400
# ..         ...    ...    ...    ...    ...        ...       ...
# 246 2024-01-25 551.95 563.46 548.46 562.00     562.00   9451900
# 247 2024-01-26 561.81 579.64 558.43 570.42     570.42  12754500
# 248 2024-01-29 571.35 578.55 562.68 575.79     575.79   6905400
# 249 2024-01-30 567.32 570.88 560.82 562.85     562.85   6181800
# 250 2024-01-31 562.85 572.15 562.04 564.11     564.11   4857600
#
# [251 rows x 7 columns]

# %% [markdown]
# Lihat bentuknya masih 251 baris dan 7 kolom yang persis sama dengan yang dilakukan di atas pada Tajuk Ikhtisar, menggunakan netflix.shape. Hal ini menyiratkan bahwa tidak ada Nilai yang Hilang dalam kumpulan data.

# %% [markdown]
# ## 4. Time Series Analysis

# %% [markdown]
# Time-series-analysis adalah teknik statistik yang kuat yang digunakan untuk menganalisis dan menginterpretasikan titik data yang dikumpulkan pada interval waktu yang berurutan. Tidak seperti analisis data cross-sectional tradisional, yang berfokus pada pengamatan pada satu titik waktu, analisis deret waktu mempelajari pola temporal, tren, dan ketergantungan yang ada dalam data. Analisis ini dapat digunakan di berbagai bidang, termasuk keuangan, ekonomi, meteorologi, dan teknik, di mana memahami perilaku suatu fenomena dari waktu ke waktu sangat penting untuk pengambilan keputusan dan prediksi. Time series data sering kali menunjukkan karakteristik unik seperti tren, musiman, autokorelasi, dan volatilitas, yang memerlukan teknik analisis khusus untuk eksplorasi dan peramalan. Melalui analisis deret waktu, para praktisi dapat menemukan wawasan yang berharga, mendeteksi anomali, memodelkan hubungan, dan membuat prediksi yang tepat mengenai hasil di masa depan, sehingga memungkinkan pengambilan keputusan dan perencanaan strategis yang proaktif. Paragraf pengantar ini menetapkan panggung untuk menyelami lebih dalam metode dan alat yang digunakan dalam time series analysis, memberdayakan analis untuk mengekstrak wawasan yang bermakna dan mendapatkan kesimpulan yang dapat ditindaklanjuti dari data temporal.

# %% [markdown]
# ### 4.1 Time Series Visualization

# %%
import matplotlib.pyplot as plt
def time_series_plot(dataframe):
    '''
    This function generates a time series plot based on the specified column.

    Args:
        dataframe: The DataFrame containing the time series data.

    Returns:
        None
    '''
    # Get the date column from the DataFrame
    x = dataframe['Date']

    # Get the column name for plotting (e.g., Open, Close, Volume)
    column_name = input("Enter the column name to plot the line graph: ")

    # Check if the specified column exists in the DataFrame
    if column_name in dataframe.columns:
        # Get the values for the specified column
        y = dataframe[column_name]

        # Plot the time series
        plt.plot(x, y)
        plt.xlabel('Date')
        plt.ylabel(column_name)
        plt.title('Time Series Plot: ' + column_name)
        plt.show()

    else:
        print("Error: The specified column does not exist in the DataFrame.")

# Call the function with your DataFrame
time_series_plot(netflix)
# Enter the column name to plot the line graph: Close
# Out:
# Enter the column name to plot the line graph: Close

# %%
time_series_plot(netflix)
# Enter the column name to plot the line graph: Open
# Out:
# Enter the column name to plot the line graph: Open

# %%
time_series_plot(netflix)
# Enter the column name to plot the line graph: Volume
# Out:
# Enter the column name to plot the line graph: Volume

# %% [markdown]
# Di sini, kita dapat melihat bahwa Open dan Close memiliki pola yang hampir sama. Mari kita lihat perbandingan berdampingan untuk mengidentifikasi wawasan apa pun, jika ada.

# %%
def time_series_plot(dataframe):
    '''
    This function generates a side-by-side comparison of time series plots for the "Open" and "Close" columns.

    Args:
        dataframe: The DataFrame containing the time series data.

    Returns:
        None
    '''

    # Get the date column from the DataFrame
    x = dataframe['Date']

    # Get the values for the "Open" and "Close" columns
    open_prices = dataframe['Open']
    close_prices = dataframe['Close']

    # Create a figure and two subplots side by side
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    # Plot the time series for the "Open" column
    axs[0].plot(x, open_prices, color='blue')
    axs[0].set_title('Open Prices')
    axs[0].set_xlabel('Date')
    axs[0].set_ylabel('Price')

    # Plot the time series for the "Close" column
    axs[1].plot(x, close_prices, color='red')
    axs[1].set_title('Close Prices')
    axs[1].set_xlabel('Date')
    axs[1].set_ylabel('Price')

    # Adjusting layout to prevent overlap of labels
    plt.tight_layout()

    # Display the plot
    plt.show()

# Call the function with your DataFrame
time_series_plot(netflix)

# %% [markdown]
# Setelah memeriksa perbandingan berdampingan antara plot deret waktu "Open" dan "Close", terlihat jelas bahwa pola yang ditunjukkan oleh kedua kolom sangat mirip. Namun, perbedaan halus dapat diamati di antara keduanya. Pada plot "Open", harga dimulai dengan sedikit kenaikan di awal hari perdagangan, yang mengindikasikan lonjakan awal aktivitas pasar. Sebaliknya, pada plot "Close", harga mengalami penurunan marjinal menjelang akhir hari perdagangan, yang mencerminkan potensi penurunan sentimen pasar saat perdagangan berakhir. Terlepas dari perbedaan kecil ini, tren dan fluktuasi menyeluruh di kedua plot sangat selaras, menunjukkan korelasi yang kuat antara harga pembukaan dan penutupan saham Netflix selama periode waktu yang dianalisis.

# %% [markdown]
# ### 4.2 Descriptive Statistics

# %%
import pandas as pd

def descriptive_statistics(dataframe):
    '''
    This function calculates descriptive statistics for the "Open" and "Close" columns of the given DataFrame.

    Args:
        dataframe: The DataFrame containing the time series data.

    Returns:
        open_stats: A dictionary containing descriptive statistics for the "Open" column.
        close_stats: A dictionary containing descriptive statistics for the "Close" column.
    '''

    # Calculate descriptive statistics for the "Open" column
    open_stats = dataframe['Open'].describe()

    # Calculate descriptive statistics for the "Close" column
    close_stats = dataframe['Close'].describe()

    return open_stats, close_stats

# Call the function with your DataFrame
open_stats, close_stats = descriptive_statistics(netflix)

# Print the descriptive statistics
print("Descriptive Statistics for the 'Open' column:")
print(open_stats)
print("\nDescriptive Statistics for the 'Close' column:")
print(close_stats)
# Out:
# Descriptive Statistics for the 'Open' column:
# count   251.00
# mean    404.18
# std      60.85
# min     287.34
# 25%     348.99
# 50%     412.00
# 75%     444.73
# max     571.35
# Name: Open, dtype: float64
#
# Descriptive Statistics for the 'Close' column:
# count   251.00
# mean    404.27
# std      61.19
# min     292.76
# 25%     348.12
# 50%     411.69
# 75%     444.94
# max     575.79
# Name: Close, dtype: float64

# %% [markdown]
# ### 4.3 Correlation Matrix

# %%
def correlation_analysis(dataframe):
    '''
    This function performs correlation analysis between the "Open", "High", "Low", and "Close" columns.

    Args:
        dataframe: The DataFrame containing the time series data.

    Returns:
        correlations: A DataFrame containing the correlation coefficients between the columns.
    '''

    # Select the columns for correlation analysis
    columns_of_interest = ['Open', 'High', 'Low', 'Close']

    # Calculate the correlation matrix
    correlations = dataframe[columns_of_interest].corr()

    return correlations

# Call the function with your DataFrame
correlations = correlation_analysis(netflix)

# Print the correlation matrix
print("Correlation Matrix:")
print(correlations)
# Out:
# Correlation Matrix:
#        Open  High  Low  Close
# Open   1.00  1.00 1.00   0.99
# High   1.00  1.00 1.00   1.00
# Low    1.00  1.00 1.00   1.00
# Close  0.99  1.00 1.00   1.00

# %% [markdown]
# Description of Insights:
# * The correlation matrix reveals the correlation coefficients between the "Open", "High", "Low", and "Close" prices of Netflix shares.
# * A correlation coefficient ranges from -1 to 1, where 1 indicates a perfect positive linear relationship, -1 indicates a perfect negative linear relationship, and 0 indicates no linear relationship.
# * In this correlation matrix:
#     * The diagonal elements represent the correlation of each variable with itself, which is always 1.
#     * Off-diagonal elements represent the correlations between pairs of variables.
# * The correlation coefficients close to 1 suggest a strong positive linear relationship between the corresponding pairs of variables.
# * Specifically:
#     * The "Open" price is highly correlated with the "High", "Low", and "Close" prices, with correlation coefficients of approximately 1.
#     * Similarly, the "High", "Low", and "Close" prices exhibit strong positive correlations among themselves, all close to 1.
# * The high correlations between these variables indicate that they move in tandem, which is typical in financial time series data where the opening, high, low, and closing prices are closely related.

# %% [markdown]
# ### 4.4 Highest and Lowest Share Prices

# %%
# Find the row with the highest closing price
max_close_row = netflix.loc[netflix['Close'].idxmax()]

# Find the row with the lowest closing price
min_close_row = netflix.loc[netflix['Close'].idxmin()]

# Find the row with the highest volume
max_volume_row = netflix.loc[netflix['Volume'].idxmax()]

# Find the row with the lowest volume
min_volume_row = netflix.loc[netflix['Volume'].idxmin()]

# Print the results
print("Date with the highest closing price:", max_close_row['Date'], "| Price:", max_close_row['Close'])
print("Date with the lowest closing price:", min_close_row['Date'], "| Price:", min_close_row['Close'])
print("Date with the highest volume:", max_volume_row['Date'], "| Volume:", max_volume_row['Volume'])
print("Date with the lowest volume:", min_volume_row['Date'], "| Volume:", min_volume_row['Volume'])
# Out:
# Date with the highest closing price: 2024-01-29 00:00:00 | Price: 575.789978
# Date with the lowest closing price: 2023-03-10 00:00:00 | Price: 292.76001
# Date with the highest volume: 2023-10-19 00:00:00 | Volume: 28074400
# Date with the lowest volume: 2023-11-24 00:00:00 | Volume: 1404700

# %% [markdown]
# ## 5. seasonality in Stock Price

# %% [markdown]
# Sekarang saya akan menggunakan Pengelompokan Agregasi pada data deret waktu ke dalam periode yang menunjukkan pola musiman yang serupa. Periode yang umum termasuk bulan, kuartal, atau bahkan hari tertentu dalam seminggu.

# %%
# Group data by month and calculate mean closing price for each month
monthly_data = netflix.groupby(netflix['Date'].dt.month)['Close'].mean()

# Visualize the mean closing price for each month
monthly_data.plot(kind='bar', xlabel='Month', ylabel='Mean Closing Price', title='Mean Closing Price by Month')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
# Group data by month and calculate mean closing price for each month
monthly_data = netflix.groupby(netflix['Date'].dt.month)['Open'].mean()

# Visualize the mean opening price for each month
monthly_data.plot(kind='bar', xlabel='Month', ylabel='Mean Opening Price', title='Mean Opening Price by Month', color='r')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %%
# !pip install seaborn

# %%
import seaborn as sns

# Calculate the correlation matrix
correlation_matrix = netflix.corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Netflix Stock Prices')
plt.show()
# Out:
# <ipython-input-57-92a9c8a44d76>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = netflix.corr()

# %%
# Create a pivot table
pivot_table = netflix.pivot_table(index='Date', values=['Open', 'High', 'Low', 'Close'], aggfunc='mean')

# Display the pivot table
print("Pivot Table:")
print(pivot_table)
# Out:
# Pivot Table:
#             Close   High    Low   Open
# Date
# 2023-02-01 361.99 365.39 349.91 353.86
# 2023-02-02 366.89 368.32 358.43 365.16
# 2023-02-03 365.90 379.43 359.00 359.08
# 2023-02-06 361.48 368.45 360.68 363.64
# 2023-02-07 362.95 364.18 354.18 358.51
# ...           ...    ...    ...    ...
# 2024-01-25 562.00 563.46 548.46 551.95
# 2024-01-26 570.42 579.64 558.43 561.81
# 2024-01-29 575.79 578.55 562.68 571.35
# 2024-01-30 562.85 570.88 560.82 567.32
# 2024-01-31 564.11 572.15 562.04 562.85
#
# [251 rows x 4 columns]

# %%
# Histogram
plt.figure(figsize=(10, 8))
plt.hist(netflix['Open'], bins=20, color='skyblue', alpha=0.7, label='Open')
plt.hist(netflix['High'], bins=20, color='salmon', alpha=0.7, label='High')
plt.hist(netflix['Low'], bins=20, color='lightgreen', alpha=0.7, label='Low')
plt.hist(netflix['Close'], bins=20, color='lightcoral', alpha=0.7, label='Close')
plt.title('Histogram of Netflix Stock Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ## 6. Predictive Analysis

# %% [markdown]
# **Prediksi Model:**
#
# Dalam bidang analisis keuangan, prediksi model memainkan peran penting dalam meramalkan masa depan lintasan harga saham. Dengan memanfaatkan teknik statistik canggih, analis dapat mengembangkan model yang memanfaatkan data historis untuk membuat prediksi yang tepat tentang harga harga di masa depan. Prediksi ini berfungsi sebagai wawasan berharga bagi investor, memandu proses pengambilan keputusan dan menginformasikan pilihan investasi strategis.

# %% [markdown]
# **Potensi Hasil Prediksi:**
#
# Hasil prediksi memiliki implikasi yang signifikan bagi investor dan pemangku kepentingan di pasar keuangan. Prediksi yang akurat memungkinkan investor untuk mengantisipasi tren pasar, mengidentifikasi peluang investasi yang menguntungkan, dan mengurangi risiko yang terkait dengan volatilitas pasar. Sebaliknya, prediksi yang tidak akurat dapat menyebabkan keputusan investasi yang tidak optimal, yang mengakibatkan kerugian finansial dan peluang yang terlewatkan. Oleh karena itu, keandalan dan ketepatan prediksi sangat penting untuk meningkatkan kinerja investasi dan memaksimalkan imbal hasil.

# %% [markdown]
# **Pendekatan: Regresi Linier:**
#
# Dalam bidang prediksi harga saham, dua pendekatan yang umum digunakan adalah Regresi Linier dan Regresi Polinomial. Teknik-teknik regresi ini bertujuan untuk membangun hubungan matematis antara variabel input, seperti harga saham historis dan volume perdagangan, dan variabel target, yang biasanya berupa harga saham di masa mendatang. Dengan menyesuaikan model regresi dengan data historis, analis dapat memperkirakan hubungan ini untuk memprediksi pergerakan harga di masa depan. Saya akan menggunakan Regresi Linier pada analisis ini.

# %% [markdown]
# **Variabel Target dan Fitur Inout:**
#
# Dalam konteks prediksi harga saham, variabel target biasanya adalah harga saham di masa depan yang yang ingin diprediksi oleh para analis. Ini bisa berupa harga penutupan saham pada hari perdagangan mendatang. Variabel input variabel input, juga dikenal sebagai fitur, adalah titik data historis yang berfungsi sebagai prediktor untuk variabel target. Ini dapat mencakup harga saham masa lalu (misalnya, harga pembukaan, tertinggi, terendah), volume perdagangan, dan indikator keuangan relevan lainnya yang dapat memengaruhi pergerakan harga saham. Dengan menganalisis hubungan historis antara variabel input dan variabel target
# variabel target, analis dapat mengembangkan model prediktif untuk meramalkan harga saham di masa depan.

# %% [markdown]
# ### 6.1 Linear Regression

# %% [markdown]
# So, I will be using Linear Regression and since we have multiple input featurs the formula will be:
#
# f
# (w , b) ( x)=w⋅ x+b=w1
# x1+w2
# x2+…+wn
# xn+b
#
# Here:
#
# f(w, b)= Representation of prediction made by Linear Regression
#
# w = weights assigned to each coefficient
#
# b = Bias Term/Intercept term
#
# x = input features where x1, x2, . .. , xn denotes individual features
#
# w1, 22,. . .,wn = weights assigned to each feature

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Extracting input features and target variable
X = netflix[['Open', 'High', 'Low', 'Volume']] # Input features: Open, High, Low, Volume
y = netflix['Close'] # Target variable: Close

# Initialize the linear regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X, y)

# Print the coefficients and intercept
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficients: [-5.15528779e-01  5.82906825e-01  9.34067273e-01  6.17473698e-08]
# Intercept: 0.755895223760831

# %%
# Make predictions on the training data
y_pred = model.predict(X)

# Plot the actual vs. predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y, y_pred, color='blue')
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--')
plt.xlabel('Actual Close Price')
plt.ylabel('Predicted Close Price')
plt.title('Actual vs. Predicted Close Price')
plt.show()

# %%
# Define the coefficients and intercept for the linear regression model
coefficients = model.coef_ # Replace with your actual coefficients
intercept = model.intercept_ # Replace with your actual intercept

# Define a function to make predictions
def predict_price(features):
  # Calculate the dot product of coefficients and features, then add the intercept
  predicted_price = np.dot(coefficients, features) + intercept
  return predicted_price

# Example input data for prediction (replace this with your actual input data)
input_features = np.array([350, 360, 345, 8000000]) # Example input features (Open, High, Low, Volume)

# Make prediction
predicted_price = predict_price(input_features)
print(f"Predicted Price is {predicted_price:.02f}")
# Out:
# Predicted Price is 352.91

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Di bidang analisis keuangan, eksplorasi harga saham Netflix melalui analisis deret waktu yang komprehensif telah mengungkap banyak sekali wawasan dan pengungkapan yang berharga. Perjalanan kami dimulai dengan pengenalan yang cermat terhadap dataset, memberikan pandangan holistik tentang konten, sumber, dan pendekatan analitis yang digunakan. Melalui lensa Analisis Data Eksplorasi (EDA), kami memulai pencarian untuk mengungkap misteri yang dikodekan dalam fluktuasi temporal kinerja saham Netflix.
#
# Tinjauan data ini memberikan gambaran panorama harga saham Netflix, mulai dari tahun 2023 hingga 2024. Kami menavigasi lautan pembersihan data, memastikan integritas dan keandalan set data kami untuk analisis lebih lanjut. Berbekal set data yang telah disempurnakan, perjalanan kami menyelidiki kedalaman analisis deret waktu, di mana kami memetakan pergerakan harga saham Netflix dari waktu ke waktu.
#
# Visualisasi deret waktu berfungsi sebagai kompas kami, memandu kami melalui gelombang turbulensi dinamika pasar. Kami mengagumi pola, tren, dan musiman yang rumit yang terjalin yang rumit yang terjalin dalam struktur harga saham Netflix. Statistik deskriptif memberikan kompas yang naik, menawarkan sebuah kompas naik, menawarkan wawasan tentang kecenderungan sentral dan variabilitas data.
#
# Matriks korelasi menerangi interaksi antara berbagai aspek harga saham Netflix, mengungkap keselarasan yang harmonis antara harga pembukaan, harga tertinggi, harga terendah, dan harga penutupan. Selain itu, eksplorasi kami menemukan titik tertinggi dan terendah dalam harga saham Netflix, menjelaskan momen-momen penting dalam perjalanan pasarnya.
#
# Ketika kami berlayar menuju cakrawala analisis prediktif, kami menemukan prospek yang menggiurkan untuk memprediksi harga saham di masa depan menggunakan teknik pembelajaran mesin yang diawasi. Meskipun perjalanan menuju pemodelan prediktif masih merupakan perjalanan untuk hari lain, dasar yang diletakkan melalui analisis deret waktu telah membuka jalan untuk pengambilan keputusan dan perencanaan strategis. perencanaan strategis.
#
# Kesimpulannya, ekspedisi kami ke dalam lautan harga saham Netflix telah menjadi perjalanan penemuan, pencerahan, dan pemberdayaan. Berbekal wawasan yang diperoleh dari analisis kami, para pemangku kepentingan diperlengkapi untuk menavigasi arus pasar keuangan yang terus berubah dengan penuh percaya diri dan kejelasan.
#
# Saat kami mengucapkan selamat tinggal pada bab pengembaraan analitis kami ini, kami berdiri di tepi jurang kemungkinan yang tak terbatas, siap untuk memulai petualangan baru, menaklukkan tantangan baru, dan menemukan harta karun baru yang tersembunyi di dalam hamparan luas eksplorasi berbasis data.
